# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchithareddy05/23CSBTB39-40/blob/main/assignment_2(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Statistics & Distributions

# %%
import scipy.stats as stats
import scipy.optimize as opt
import numpy as np  # Import numpy before using it
import matplotlib.pyplot as plt
import seaborn as sns

data1 = np.random.randn(50)
data2 = np.random.randn(50) + 0.5
mean1, mean2 = np.mean(data1), np.mean(data2)
std1, std2 = np.std(data1, ddof=1), np.std(data2, ddof=1)
n1, n2 = len(data1), len(data2)
t_manual = (mean1 - mean2) / np.sqrt(std1**2/n1 + std2**2/n2)
t_scipy, p_val = stats.ttest_ind(data1, data2)

# %%
x = np.linspace(0, 1, 100)
beta_pdf = stats.beta.pdf(x, a=2, b=5)
beta_cdf = stats.beta.cdf(x, a=2, b=5)
plt.plot(x, beta_pdf, label="PDF")
plt.plot(x, beta_cdf, label="CDF")
plt.legend()
plt.title("Beta Distribution")
plt.show()

# %%
data = np.random.randn(100)
ks_stat, ks_pval = stats.kstest(data, 'norm')

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.randn(100)
sns.kdeplot(data, fill=True)
plt.title("Kernel Density Estimation")
plt.show()

# %%
data = np.random.randn(1000)
skewness = stats.skew(data)
kurtosis = stats.kurtosis(data)

# %%
data = np.random.gamma(shape=2, scale=1, size=1000)
params = stats.gamma.fit(data)

# %%
data = np.random.randn(100)
mean, std = np.mean(data), np.std(data)
ci_mean = stats.norm.interval(0.95, loc=mean, scale=std/np.sqrt(len(data)))

# %%
def mutual_information(x, y):
    hist_2d, _, _ = np.histogram2d(x, y, bins=20)
    pxy = hist_2d / np.sum(hist_2d)
    px = np.sum(pxy, axis=1)
    py = np.sum(pxy, axis=0)
    pxy_nonzero = pxy[pxy > 0]
    mi = np.sum(pxy_nonzero * np.log(pxy_nonzero / (px[:, None] * py[None, :])))
    return mi

# %%
observed = np.array([20, 30, 50])
expected = np.array([25, 25, 50])
chi2_stat, chi2_pval = stats.chisquare(observed, expected)

# %%
#Sparse Matrices & Graphs

# %%
from scipy.sparse import diags, csr_matrix, linalg
import numpy as np
import networkx as nx
size = 10
main_diag = 2 * np.ones(size)
off_diag = -np.ones(size-1)
diagonals = [off_diag, main_diag, off_diag]
Laplacian = diags(diagonals, [-1, 0, 1]).toarray()

# %%
A = diags([1, -2, 1], [-1, 0, 1], shape=(size, size)).tocsc()
b = np.ones(size)
x = linalg.spsolve(A, b)

# %%
import numpy as np
import scipy.sparse.csgraph as csgraph
graph = np.random.rand(5, 5)
graph[graph > 0.5] = 0
shortest_paths = csgraph.dijkstra(graph)  # Use the correctly imported module

# %%
dense = np.random.randint(0, 2, (5, 5))
sparse_matrix = csr_matrix(dense)
recovered_dense = sparse_matrix.toarray()

# %%
#Signal & Fourier Transforms

# %%
import scipy.fftpack as fft
import pywt
import scipy.signal as sig
t = np.linspace(0, 1, 1000)
signal = np.sin(2 * np.pi * 50 * t) + np.random.normal(0, 0.5, len(t))
b, a = sig.butter(4, 0.1, 'low')
filtered_signal = sig.filtfilt(b, a, signal)

# %%
image = np.random.rand(50, 50)
dft = np.fft.fft2(image)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = np.log(np.abs(dft_shift) + 1)

# %%
window = np.hanning(len(signal))
windowed_signal = signal * window
fft_result = fft.fft(windowed_signal)
freqs = fft.fftfreq(len(signal))

# %%
coeffs = pywt.wavedec(signal, 'db1', level=4)
threshold = np.median(np.abs(coeffs[-1])) / 0.6745
coeffs = [pywt.threshold(c, threshold, mode='soft') for c in coeffs]
denoised_signal = pywt.waverec(coeffs, 'db1')

# %%
signal1 = np.sin(2 * np.pi * 5 * t)
signal2 = np.sin(2 * np.pi * 10 * t)
convolved_signal = np.convolve(signal1, signal2, mode='full')

# %%
#Basic and Advanced Plotting

# %%
from matplotlib import animation
fig, ax = plt.subplots()
x = np.linspace(0, 2*np.pi, 100)
line, = ax.plot(x, np.sin(x))

def update(frame):
    line.set_ydata(np.sin(x + frame / 10))
    return line,

ani = animation.FuncAnimation(fig, update, frames=100, interval=50)
plt.show()

# %%
data = np.random.rand(10, 10)
plt.imshow(data, cmap="coolwarm", aspect="auto")
plt.colorbar()
plt.title("Heatmap")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/matplotlib/animation.py:908: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x) * 100
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(x, y1, label="Sine Wave")
ax2.plot(x, y2, label="Cosine (scaled)", color="red")
ax1.set_ylabel("Sin(x)")
ax2.set_ylabel("Cos(x) * 100")
plt.show()

# %%
data1 = np.random.randn(100)
data2 = np.random.randn(100) + 2
sns.histplot(data1, kde=True, color="blue", alpha=0.6)
sns.histplot(data2, kde=True, color="red", alpha=0.6)
plt.title("Histogram and KDE Overlay")
plt.show()

# %%
theta = np.linspace(0, 2*np.pi, 100)
r = np.abs(np.sin(theta))
plt.polar(theta, r)
plt.title("Polar Plot of Sin(θ)")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
X, Y = np.meshgrid(np.linspace(-5, 5, 50), np.linspace(-5, 5, 50))
Z = np.sin(np.sqrt(X**2 + Y**2))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap="viridis", alpha=0.8)
ax.contour(X, Y, Z, offset=-1, cmap="coolwarm")
plt.show()

# %%
data = [np.random.randn(100) + i for i in range(4)]
sns.violinplot(data=data)
plt.title("Violin Plot")
plt.show()

# %%
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)
x = np.linspace(0, 10, 100)
axs[0, 0].plot(x, np.sin(x))
axs[0, 1].plot(x, np.cos(x))
axs[1, 0].hist(np.random.randn(100))
axs[1, 1].scatter(np.random.rand(50), np.random.rand(50))
plt.show()

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x) + np.cos(2*x)
plt.plot(x, y)
plt.xlabel("Position")
plt.ylabel("Momentum")
plt.title("Phase Space Trajectory")
plt.show()

# %%
from sklearn.decomposition import PCA
data = np.random.randn(100, 3)
pca = PCA(n_components=2).fit_transform(data)
plt.scatter(pca[:, 0], pca[:, 1])
plt.title("PCA 2D Projection")
plt.show()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
pca_3d = PCA(n_components=3).fit_transform(data)
ax.scatter(pca_3d[:, 0], pca_3d[:, 1], pca_3d[:, 2])
plt.title("PCA 3D Projection")
plt.show()

# %%
plt.scatter(np.random.rand(100), np.random.rand(100))
plt.title("Interactive Scatter Plot")
plt.show()

# %%
data = np.random.rand(5, 3) * 10
errors = np.random.rand(5, 3)
x = np.arange(5)
plt.bar(x - 0.2, data[:, 0], width=0.2, yerr=errors[:, 0], label="Series 1")
plt.bar(x, data[:, 1], width=0.2, yerr=errors[:, 1], label="Series 2")
plt.bar(x + 0.2, data[:, 2], width=0.2, yerr=errors[:, 2], label="Series 3")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(np.linspace(0, 10, 100), np.sin(np.linspace(0, 10, 100)))
plt.savefig("plot.svg")
plt.savefig("plot.pdf")
plt.savefig("plot.png", dpi=300)

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
axs[0, 0].plot(np.linspace(0, 10, 100), np.sin(np.linspace(0, 10, 100)))
axs[0, 1].hist(np.random.randn(100))
axs[1, 0].scatter(np.random.rand(50), np.random.rand(50))
axs[1, 1].boxplot([np.random.randn(100), np.random.randn(100)+1])
plt.show()

# %%
from matplotlib.colors import LinearSegmentedColormap
custom_cmap = LinearSegmentedColormap.from_list("custom", ["blue", "white", "red"])
image_data = np.random.rand(10, 10)
plt.imshow(image_data, cmap=custom_cmap)
plt.colorbar()
plt.title("Custom Colormap")
plt.show()

# %%
# Scientific & Real-World Visualizations

# %%
import matplotlib.pyplot as plt
t = np.linspace(0, 2, 100)
g = 9.81
v0 = 10
theta = np.radians(45)
x = v0 * np.cos(theta) * t
y = v0 * np.sin(theta) * t - 0.5 * g * t**2
plt.plot(x, y)
plt.xlabel("Distance")
plt.ylabel("Height")
plt.title("Projectile Motion")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
X = np.random.rand(50, 1) * 10
y = 3 * X.squeeze() + 7 + np.random.randn(50) * 2
model = LinearRegression().fit(X, y)
residuals = y - model.predict(X)
plt.hist(residuals, bins=10, edgecolor='black')
plt.title("Histogram of Residuals")
plt.show()

# %%
import seaborn as sns
data = np.random.rand(10, 10)
corr_matrix = np.corrcoef(data)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
x = np.linspace(-2, 2, 100)
y = x**2
plt.plot(x, y, label="Objective Function")
plt.scatter([-1, 0, 1], [1, 0, 1], color='red', label="Optimization Steps")
plt.legend()
plt.show()

# %%
import scipy.fftpack as fft
t = np.linspace(0, 1, 1000)
signal = np.sin(2*np.pi*50*t) + np.sin(2*np.pi*120*t)
transformed = fft.fft(signal)
freqs = fft.fftfreq(len(signal))
plt.plot(freqs, np.abs(transformed))
plt.title("Fourier Transform")
plt.show()

# %%
x = np.linspace(0, 10, 10)
y = np.sin(x)
x_fine = np.linspace(0, 10, 100)
y_linear = np.interp(x_fine, x, y)
plt.plot(x_fine, y_linear, label="Linear Interpolation")
plt.scatter(x, y, color='red', label="Original Points")
plt.legend()
plt.show()

# %%
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
data, _ = make_classification(
    n_samples=100,
    n_features=2,
    n_informative=2,
    n_redundant=0,
    n_repeated=0
)
kmeans = KMeans(n_clusters=3, n_init=10).fit(data)
plt.scatter(data[:, 0], data[:, 1], c=kmeans.labels_, cmap='viridis')
plt.title("Clustering Visualization")
plt.show()

# %%
data = [np.random.randn(100) + i for i in range(5)]
plt.boxplot(data)
plt.title("Boxplot of Multiple Distributions")
plt.show()

# %%
time_series = np.random.randn(100).cumsum()
plt.plot(time_series, label="Time Series")
plt.plot(np.convolve(time_series, np.ones(5)/5, mode='valid'), label="Moving Average", color='red')
plt.legend()
plt.show()

# %%
X, y = make_classification(n_samples=200, n_features=2, n_classes=2,n_informative=2, n_redundant=0, n_repeated=0)
model = LinearRegression().fit(X, y)
xx, yy = np.meshgrid(np.linspace(X[:,0].min(), X[:,0].max(), 50),
                     np.linspace(X[:,1].min(), X[:,1].max(), 50))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.6)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='black')
plt.title("Decision Boundaries")
plt.show()

# %%
complex_signal = np.exp(1j * np.linspace(0, 2*np.pi, 100))
plt.plot(np.real(complex_signal), label="Real Part")
plt.plot(np.imag(complex_signal), label="Imaginary Part")
plt.legend()
plt.show()

# %%
import scipy.signal as sig
b, a = sig.butter(4, 0.2)
w, h = sig.freqz(b, a)
plt.plot(w, np.abs(h))
plt.title("Filter Frequency Response")
plt.show()

# %%
X = np.linspace(-5, 5, 50)
Y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(X, Y, Z)
plt.show()

# %%
u = np.linspace(0, 2*np.pi, 30)
v = np.linspace(0, np.pi, 30)
u, v = np.meshgrid(u, v)
x = np.sin(v) * np.cos(u)
y = np.sin(v) * np.sin(u)
z = np.cos(v)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(x, y, z)
plt.show()

# %%
fig, axs = plt.subplots(2, 2)
x = np.linspace(0, 10, 100)
axs[0, 0].plot(x, np.sin(x), label="Sin")
axs[0, 1].scatter(np.random.rand(50), np.random.rand(50))
axs[1, 0].hist(np.random.randn(100))
axs[1, 1].boxplot([np.random.randn(100), np.random.randn(100)+2])
plt.show()
